# %% [markdown]
# ##Prediccion Inmuebles

# %%
# Como siempre, primero nos importamos las librerías con las que vamos a estar trabajando

import requests # Nos va a permitir hacer llamados con el protocolo HTTP
import json # Nos va a permitir trabajar con los archivos JSON
import pandas as pd # Nuestra librería amiga de siempre que nos permite trabajar con datos tabulares
import numpy as np # numpy para trabajar con operaciones matemáticas y arrays

# %%
# Nos definimos una función que nos va a dejar acceder a la información que nos devuelva el URL que pongamos
# en el argumento. Recuerden que el URL es la dirección del sitio web que vamos a usar

def get_response(url):
    try:
        response = requests.get(url, timeout=3)
        response.raise_for_status()
        return response
    except requests.exceptions.HTTPError as errh:
        print ("Http Error:",errh)
    except requests.exceptions.ConnectionError as errc:
        print ("Error Connecting:",errc)
    except requests.exceptions.Timeout as errt:
        print ("Timeout Error:",errt)
    except requests.exceptions.RequestException as err:
        print ("OOps: Something Else",err)

# %% [markdown]
# importante: Mensaje de ARNALDO
# Para evitar la necesidad del token y otras yerbas hice varios pedidos de dipología de deptos segun áreas descriptas en este mapa: https://www.google.com/maps/d/edit?mid=1MHaRRb-eueaA_3yGywHA-wrNA7sFpR6Z&usp=sharing
#
# Básicamente lo que hago es copiar varios chunks de código donde cambio la latitud y logitud en las URL (me costó mucho!) y voy llamando a los 1050 registros de cada área. Esto aplica solo para los deptos, casa y cocheras viene por defecto, no hay muchas con 1000 estamos.

# %%
r.json()["paging"]["total"]
# Out:
# 4467

# %%
#CASAS
# Primero indicamos la consulta que vamos a hacer
url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-33.01_-32.90,lon:-60.771_-60.618&category=MLA401685&limit=50&offset=0#json' #inmueble / CASAS  / venta / propiedades individuales
offset=0 #Arrancamos con el offset 0

offset=0 #Arrancamos con el offset 0
url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-33.01_-32.90,lon:-60.771_-60.618&category=MLA401685&limit=50&offset=0#json'.format(offset)
r = get_response(url) #Vemos los resultados de la consulta
maximum = int(str(r.json()["paging"]["total"])) #Consultamos cuál es el número máximo de resultados

print('Encontramos {} resultados para nuestra consulta'.format(maximum))

# Vamos a forzarnos a buscar pocos resultados para seguir testeando y no perder tanta velocidad
# Cuando vayamos full mode, esta linea de abajo hay que comentarla o borrarla
maximum=200

# Ahora, sabiendo esto, vamos a traer todos los resultados iterando y aumentando el offset en cada loop.
# Recuerden que solo podemos traer de a tandas de a 50 resultados
item_list_casas = []
while r.status_code == 200 and offset <= maximum:
    url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-33.01_-32.90,lon:-60.771_-60.618&category=MLA401685&limit=50&offset={}#json'.format(offset)
    r = get_response(url)
    data = r.json()
    length = len(data['results'])
    for i in range(length):
        item_id = data['results'][i]['id']
        item_list_casas.append(item_id)
    print("Porcentaje de completitud: {:0.2%}".format(offset/maximum),end='\r')
    offset += 50
        
len(item_list_casas)
# Out:
# Encontramos 2728 resultados para nuestra consulta
# Porcentaje de completitud: 100.00%
# 250

# %%
#en esta sentencia detectamos si hay o no items repetidos
print(len(item_list_casas))
print(len(set(item_list_casas)))
# Out:
# 250
# 250

# %% [markdown]
# #DEPTOS 1a / zona centro1
# # Primero indicamos la consulta que vamos a hacer
# url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.9446_-32.9228,lon:-60.66146_-60.64312&category=MLA401686&limit=50&offset=0#json' #inmueble / deptos  / venta / propiedades individuales / zonadentr!
# offset=0 #Arrancamos con el offset 0
#
# offset=0 #Arrancamos con el offset 0
# url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.9446_-32.9228,lon:-60.66146_-60.64312&category=MLA401686&limit=50&offset=0#json'.format(offset)
# r = get_response(url) #Vemos los resultados de la consulta
# maximum = int(str(r.json()["paging"]["total"])) #Consultamos cuál es el número máximo de resultados
#
# print('Encontramos {} resultados para nuestra consulta'.format(maximum))
#
# # Vamos a forzarnos a buscar pocos resultados para seguir testeando y no perder tanta velocidad
# # Cuando vayamos full mode, esta linea de abajo hay que comentarla o borrarla
# maximum=1000
#
# # Ahora, sabiendo esto, vamos a traer todos los resultados iterando y aumentando el offset en cada loop.
# # Recuerden que solo podemos traer de a tandas de a 50 resultados
# item_list_deptos1a = []
# while r.status_code == 200 and offset <= maximum:
#     url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.9446_-32.9228,lon:-60.66146_-60.64312&category=MLA401686&limit=50&offset={}#json'.format(offset)
#     r = get_response(url)
#     data = r.json()
#     length = len(data['results'])
#     for i in range(length):
#         item_id = data['results'][i]['id']
#         item_list_deptos1a.append(item_id)
#     print("Porcentaje de completitud: {:0.2%}".format(offset/maximum),end='\r')
#     offset += 50
#
# len(item_list_deptos1a)

# %% [markdown]
# print(len(item_list_deptos1a))
# print(len(set(item_list_deptos1a)))

# %% [markdown]
# #DEPTOS 1b / zona centro2
# # Primero indicamos la consulta que vamos a hacer
# url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.9446_-32.9228,lon:-60.64141_-60.62012&category=MLA401686&limit=50&offset=0#json' #inmueble / deptos  / venta / propiedades individuales / zonadentr!
# offset=0 #Arrancamos con el offset 0
#
# offset=0 #Arrancamos con el offset 0
# url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.9446_-32.9228,lon:-60.64141_-60.62012&category=MLA401686&limit=50&offset=0#json'.format(offset)
# r = get_response(url) #Vemos los resultados de la consulta
# maximum = int(str(r.json()["paging"]["total"])) #Consultamos cuál es el número máximo de resultados
#
# print('Encontramos {} resultados para nuestra consulta'.format(maximum))
#
# # Vamos a forzarnos a buscar pocos resultados para seguir testeando y no perder tanta velocidad
# # Cuando vayamos full mode, esta linea de abajo hay que comentarla o borrarla
# maximum=1000
#
# # Ahora, sabiendo esto, vamos a traer todos los resultados iterando y aumentando el offset en cada loop.
# # Recuerden que solo podemos traer de a tandas de a 50 resultados
# item_list_deptos1b = []
# while r.status_code == 200 and offset <= maximum:
#     url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.9446_-32.9228,lon:-60.64141_-60.62012&category=MLA401686&limit=50&offset={}#json'.format(offset)
#     r = get_response(url)
#     data = r.json()
#     length = len(data['results'])
#     for i in range(length):
#         item_id = data['results'][i]['id']
#         item_list_deptos1b.append(item_id)
#     print("Porcentaje de completitud: {:0.2%}".format(offset/maximum),end='\r')
#     offset += 50
#
# len(item_list_deptos1b)

# %% [markdown]
# print(len(item_list_deptos1b))
# print(len(set(item_list_deptos1b)))

# %%
#DEPTOS 1c / zona centro3
# Primero indicamos la consulta que vamos a hacer
url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.96164_-32.94579,lon:-60.66146_-60.64312&category=MLA401686&limit=50&offset=0#json' #inmueble / deptos  / venta / propiedades individuales / zonadentr!
offset=0 #Arrancamos con el offset 0

offset=0 #Arrancamos con el offset 0
url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.96164_-32.94579,lon:-60.66146_-60.64312&category=MLA401686&limit=50&offset=0#json'.format(offset)
r = get_response(url) #Vemos los resultados de la consulta
maximum = int(str(r.json()["paging"]["total"])) #Consultamos cuál es el número máximo de resultados

print('Encontramos {} resultados para nuestra consulta'.format(maximum))

# Vamos a forzarnos a buscar pocos resultados para seguir testeando y no perder tanta velocidad
# Cuando vayamos full mode, esta linea de abajo hay que comentarla o borrarla. 300 para mas velocidad
maximum=200

# Ahora, sabiendo esto, vamos a traer todos los resultados iterando y aumentando el offset en cada loop.
# Recuerden que solo podemos traer de a tandas de a 50 resultados
item_list_deptos1c = []
while r.status_code == 200 and offset <= maximum:
    url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.96164_-32.94579,lon:-60.66146_-60.64312&category=MLA401686&limit=50&offset={}#json'.format(offset)
    r = get_response(url)
    data = r.json()
    length = len(data['results'])
    for i in range(length):
        item_id = data['results'][i]['id']
        item_list_deptos1c.append(item_id)
    print("Porcentaje de completitud: {:0.2%}".format(offset/maximum),end='\r')
    offset += 50
        
len(item_list_deptos1c)
# Out:
# Encontramos 5796 resultados para nuestra consulta
# Porcentaje de completitud: 100.00%
# 250

# %%
print(len(item_list_deptos1c))
print(len(set(item_list_deptos1c)))
# Out:
# 250
# 250

# %% [markdown]
# #DEPTOS 1d / zona centro3
# # Primero indicamos la consulta que vamos a hacer
# url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.9446_-32.9228,lon:-60.63956_-60.61964&category=MLA401686&limit=50&offset=0#json' #inmueble / deptos  / venta / propiedades individuales / zonadentr!
# offset=0 #Arrancamos con el offset 0
#
# offset=0 #Arrancamos con el offset 0
# url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.9446_-32.9228,lon:-60.63956_-60.61964&category=MLA401686&limit=50&offset=0#json'.format(offset)
# r = get_response(url) #Vemos los resultados de la consulta
# maximum = int(str(r.json()["paging"]["total"])) #Consultamos cuál es el número máximo de resultados
#
# print('Encontramos {} resultados para nuestra consulta'.format(maximum))
#
# # Vamos a forzarnos a buscar pocos resultados para seguir testeando y no perder tanta velocidad
# # Cuando vayamos full mode, esta linea de abajo hay que comentarla o borrarla
# maximum=1000
#
# # Ahora, sabiendo esto, vamos a traer todos los resultados iterando y aumentando el offset en cada loop.
# # Recuerden que solo podemos traer de a tandas de a 50 resultados
# item_list_deptos1d = []
# while r.status_code == 200 and offset <= maximum:
#     url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.9446_-32.9228,lon:-60.63956_-60.61964&category=MLA401686&limit=50&offset={}#json'.format(offset)
#     r = get_response(url)
#     data = r.json()
#     length = len(data['results'])
#     for i in range(length):
#         item_id = data['results'][i]['id']
#         item_list_deptos1d.append(item_id)
#     print("Porcentaje de completitud: {:0.2%}".format(offset/maximum),end='\r')
#     offset += 50
#
# len(item_list_deptos1d)

# %% [markdown]
# print(len(item_list_deptos1d))
# print(len(set(item_list_deptos1d)))

# %% [markdown]
# #DEPTOS 2 / zona sur
# # Primero indicamos la consulta que vamos a hacer
# url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-33.01_-32.963,lon:-60.657_-60.618&category=MLA401686&limit=50&offset=0#json' #inmueble / deptos  / venta / propiedades individuales / zonasur!
# offset=0 #arranco mas arriba para no pisar los items anteriores
#
# offset=0 #Arrancamos con el offset 0
# url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-33.01_-32.963,lon:-60.657_-60.618&category=MLA401686&limit=50&offset=0#json'.format(offset)
# r = get_response(url) #Vemos los resultados de la consulta
# maximum = int(str(r.json()["paging"]["total"])) #Consultamos cuál es el número máximo de resultados
#
# print('Encontramos {} resultados para nuestra consulta'.format(maximum))
#
# # Vamos a forzarnos a buscar pocos resultados para seguir testeando y no perder tanta velocidad
# # Cuando vayamos full mode, esta linea de abajo hay que comentarla o borrarla
# maximum=1000
#
# # Ahora, sabiendo esto, vamos a traer todos los resultados iterando y aumentando el offset en cada loop.
# # Recuerden que solo podemos traer de a tandas de a 50 resultados
# item_list_deptos2 = []
# while r.status_code == 200 and offset <= maximum:
#     url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-33.01_-32.963,lon:-60.657_-60.618&category=MLA401686&limit=50&offset={}#json'.format(offset)
#     r = get_response(url)
#     data = r.json()
#     length = len(data['results'])
#     for i in range(length):
#         item_id = data['results'][i]['id']
#         item_list_deptos2.append(item_id)
#     print("Porcentaje de completitud: {:0.2%}".format(offset/maximum),end='\r')
#     offset += 50
#
# len(item_list_deptos2)

# %%
#DEPTOS 3 / macrocentro1
# Primero indicamos la consulta que vamos a hacer
url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.95348_-32.922294,lon:-60.73433_-60.66584&category=MLA401686&limit=50&offset=0#json' #inmueble / deptos  / venta / propiedades individuales 
offset=0 #arranco mas arriba para no pisar los items anteriores

offset=0 #Arrancamos con el offset 0
url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.95348_-32.922294,lon:-60.73433_-60.66584&category=MLA401686&limit=50&offset=0#json'.format(offset)
r = get_response(url) #Vemos los resultados de la consulta
maximum = int(str(r.json()["paging"]["total"])) #Consultamos cuál es el número máximo de resultados

print('Encontramos {} resultados para nuestra consulta'.format(maximum))

# Vamos a forzarnos a buscar pocos resultados para seguir testeando y no perder tanta velocidad
# Cuando vayamos full mode, esta linea de abajo hay que comentarla o borrarla
maximum=1000

# Ahora, sabiendo esto, vamos a traer todos los resultados iterando y aumentando el offset en cada loop.
# Recuerden que solo podemos traer de a tandas de a 50 resultados
item_list_deptos3 = []
while r.status_code == 200 and offset <= maximum:
    url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.95348_-32.922294,lon:-60.73433_-60.66584&category=MLA401686&limit=50&offset={}#json'.format(offset)
    r = get_response(url)
    data = r.json()
    length = len(data['results'])
    for i in range(length):
        item_id = data['results'][i]['id']
        item_list_deptos3.append(item_id)
    print("Porcentaje de completitud: {:0.2%}".format(offset/maximum),end='\r')
    offset += 50
        
len(item_list_deptos3)
# Out:
# Encontramos 4467 resultados para nuestra consulta
# Porcentaje de completitud: 100.00%
# 1050

# %% [markdown]
# print(len(item_list_deptos3))
# print(len(set(item_list_deptos3)))

# %% [markdown]
# #DEPTOS 4 / norte
# # Primero indicamos la consulta que vamos a hacer
# url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.92011_-32.86057,lon:-60.73368_-60.66584&category=MLA401686&limit=50&offset=0#json' #inmueble / deptos  / venta / propiedades individuales
# offset=0 #arranco mas arriba para no pisar los items anteriores
#
# offset=0 #Arrancamos con el offset 0
# url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.92011_-32.86057,lon:-60.73368_-60.66584&category=MLA401686&limit=50&offset=0#json'.format(offset)
# r = get_response(url) #Vemos los resultados de la consulta
# maximum = int(str(r.json()["paging"]["total"])) #Consultamos cuál es el número máximo de resultados
#
# print('Encontramos {} resultados para nuestra consulta'.format(maximum))
#
# # Vamos a forzarnos a buscar pocos resultados para seguir testeando y no perder tanta velocidad
# # Cuando vayamos full mode, esta linea de abajo hay que comentarla o borrarla
# maximum=1000
#
# # Ahora, sabiendo esto, vamos a traer todos los resultados iterando y aumentando el offset en cada loop.
# # Recuerden que solo podemos traer de a tandas de a 50 resultados
# item_list_deptos4 = []
# while r.status_code == 200 and offset <= maximum:
#     url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-32.92011_-32.86057,lon:-60.73368_-60.66584&category=MLA401686&limit=50&offset={}#json'.format(offset)
#     r = get_response(url)
#     data = r.json()
#     length = len(data['results'])
#     for i in range(length):
#         item_id = data['results'][i]['id']
#         item_list_deptos4.append(item_id)
#     print("Porcentaje de completitud: {:0.2%}".format(offset/maximum),end='\r')
#     offset += 50
#
# len(item_list_deptos4)

# %% [markdown]
# print(len(item_list_deptos4))
# print(len(set(item_list_deptos4)))

# %% [markdown]
# #DEPTOS 5 / suroeste
# # Primero indicamos la consulta que vamos a hacer
# url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-33.01295_-32.95823,lon:-60.73368_-60.66584&category=MLA401686&limit=50&offset=0#json' #inmueble / deptos  / venta / propiedades individuales
# offset=0 #arranco mas arriba para no pisar los items anteriores
#
# offset=0 #Arrancamos con el offset 0
# url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-33.01295_-32.95823,lon:-60.73368_-60.66584&category=MLA401686&limit=50&offset=0#json'.format(offset)
# r = get_response(url) #Vemos los resultados de la consulta
# maximum = int(str(r.json()["paging"]["total"])) #Consultamos cuál es el número máximo de resultados
#
# print('Encontramos {} resultados para nuestra consulta'.format(maximum))
#
# # Vamos a forzarnos a buscar pocos resultados para seguir testeando y no perder tanta velocidad
# # Cuando vayamos full mode, esta linea de abajo hay que comentarla o borrarla
# maximum=1000
#
# # Ahora, sabiendo esto, vamos a traer todos los resultados iterando y aumentando el offset en cada loop.
# # Recuerden que solo podemos traer de a tandas de a 50 resultados
# item_list_deptos5 = []
# while r.status_code == 200 and offset <= maximum:
#     url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-33.01295_-32.95823,lon:-60.73368_-60.66584&category=MLA401686&limit=50&offset={}#json'.format(offset)
#     r = get_response(url)
#     data = r.json()
#     length = len(data['results'])
#     for i in range(length):
#         item_id = data['results'][i]['id']
#         item_list_deptos5.append(item_id)
#     print("Porcentaje de completitud: {:0.2%}".format(offset/maximum),end='\r')
#     offset += 50
#
# len(item_list_deptos5)

# %% [markdown]
# print(len(item_list_deptos5))
# print(len(set(item_list_deptos5)))

# %% [markdown]
# #cocheras
# # Primero indicamos la consulta que vamos a hacer
# url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-33.01_-32.90,lon:-60.771_-60.618&category=MLA50543&limit=50&offset=0#json' #inmueble / cocheras  / venta
#
# offset=0 #Arrancamos con el offset 0
# url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-33.01_-32.90,lon:-60.771_-60.618&category=MLA50543&limit=50&offset=0#json'.format(offset)
# r = get_response(url) #Vemos los resultados de la consulta
# maximum = int(str(r.json()["paging"]["total"])) #Consultamos cuál es el número máximo de resultados
#
# print('Encontramos {} resultados para nuestra consulta'.format(maximum))
#
# # Vamos a forzarnos a buscar pocos resultados para seguir testeando y no perder tanta velocidad
# # Cuando vayamos full mode, esta linea de abajo hay que comentarla o borrarla. cambio a 300 para mas velocidad
# maximum=200
#
# # Ahora, sabiendo esto, vamos a traer todos los resultados iterando y aumentando el offset en cada loop.
# # Recuerden que solo podemos traer de a tandas de a 50 resultados
# item_list_cocheras = []
# while r.status_code == 200 and offset <= maximum:
#     url='https://api.mercadolibre.com/sites/MLA/search?item_location=lat:-33.01_-32.90,lon:-60.771_-60.618&category=MLA50543&limit=50&offset={}#json'.format(offset)
#     r = get_response(url)
#     data = r.json()
#     length = len(data['results'])
#     for i in range(length):
#         item_id = data['results'][i]['id']
#         item_list_cocheras.append(item_id)
#     print("Porcentaje de completitud: {:0.2%}".format(offset/maximum),end='\r')
#     offset += 50
#
# len(item_list_cocheras)

# %% [markdown]
# print(len(item_list_cocheras))
# print(len(set(item_list_cocheras)))

# %%
##acá unifico los items en una sola lista (las listas comentadas signignifica que vamos a laburar con una lista de items más chica)
item_list = []
item_list.extend(item_list_casas)
#item_list.extend(item_list_cocheras)
#item_list.extend(item_list_deptos1a)  
#item_list.extend(item_list_deptos1b)  
#item_list.extend(item_list_deptos1c)  
#item_list.extend(item_list_deptos1d)  
#item_list.extend(item_list_deptos2)  
#item_list.extend(item_list_deptos3)  
#item_list.extend(item_list_deptos4)  
#item_list.extend(item_list_deptos5)  

len (item_list) #verifico que se hayan pegado todos
# Out:
# 250

# %%
print(len(item_list))
print(len(set(item_list)))
# Out:
# 250
# 250

# %% [markdown]
# MEnsaje de Arnaldo: acá abria que quedarse solo con los ítems únicos: creo que 8296 es una buena base. JQ; para trabajar comentamos parte de la base

# %%
#Ahora, teniendo el listado de los items, nos vamos a traer las características de ellos
final_list = []
for i in range(len(item_list)):
    item="https://api.mercadolibre.com/items/{}".format(item_list[i])
    item_add = requests.get(item)
    item_add = item_add.json()
    final_list.append(item_add)
    print("Porcentaje de completitud: {:0.2%}".format((i+1)/len(item_list)),end='\r')
# Out:
# Porcentaje de completitud: 100.00%

# %%
#Exploremos las llaves que tiene el archivo
final_list[0].keys()
# Out:
# dict_keys(['id', 'site_id', 'title', 'subtitle', 'seller_id', 'category_id', 'official_store_id', 'price', 'base_price', 'original_price', 'currency_id', 'initial_quantity', 'available_quantity', 'sold_quantity', 'sale_terms', 'buying_mode', 'listing_type_id', 'start_time', 'stop_time', 'condition', 'permalink', 'thumbnail_id', 'thumbnail', 'secure_thumbnail', 'pictures', 'video_id', 'descriptions', 'accepts_mercadopago', 'non_mercado_pago_payment_methods', 'shipping', 'international_delivery_mode', 'seller_address', 'seller_contact', 'location', 'coverage_areas', 'attributes', 'warnings', 'listing_source', 'variations', 'status', 'sub_status', 'tags', 'warranty', 'catalog_product_id', 'domain_id', 'parent_item_id', 'differential_pricing', 'deal_ids', 'automatic_relist', 'date_created', 'last_updated', 'health', 'catalog_listing', 'channels'])

# %%
#Veamos el primer elemento
final_list[3]
# Out:
# {'id': 'MLA929584796',
#  'site_id': 'MLA',
#  'title': 'Casa - Rosario',
#  'subtitle': None,
#  'seller_id': 685332863,
#  'category_id': 'MLA401685',
#  'official_store_id': None,
#  'price': 650000,
#  'base_price': 650000,
#  'original_price': None,
#  'currency_id': 'USD',
#  'initial_quantity': 1,
#  'available_quantity': 1,
#  'sold_quantity': 0,
#  'sale_terms': [{'id': 'IS_FINANCEABLE',
#    'name': 'Es financiable',
#    'value_id': '242084',
#    'value_name': 'No',
#    'value_struct': None,
#    'values': [{'id': '242084', 'name': 'No', 'struct': None}]}],
#  'buying_mode': 'classified',
#  'listing_type_id': 'gold_premium',
#  'start_time': '2021-07-15T15:06:23.000Z',
#  'stop_time': '2021-09-13T04:00:00.000Z',
#  'condition': 'used',
#  'permalink': 'https://casa.mercadolibre.com.ar/MLA-929584796-casa-rosario-_JM',
#  'thumbnail_id': '954343-MLA46752983128_072021',
#  'thumbnail': 'http://http2.mlstatic.com/D_954343-MLA46752983128_072021-I.jpg',
# ...

# %%
#Transformamos los datos a tabla con pd.json_normalize
data=pd.json_normalize(final_list)
data.head()
# Out:
#              id site_id                                              title  \
# 0  MLA929073106     MLA  Venta Casa 4 Dormitorios. Jardín. - Fisherton,...
# 1  MLA929575204     MLA                        Edificio Silene Ii - Fundar
# 2  MLA929275447     MLA  Casa De Pasillo En Barrio Martin, A Reciclar, ...
# 3  MLA929584796     MLA                                     Casa - Rosario
# 4  MLA929280935     MLA                             Casa - Rep.de La Sexta
#
#   subtitle  seller_id category_id  official_store_id   price  base_price  \
# 0     None  306853491   MLA401685             2017.0  460000      460000
# 1     None  395991540   MLA401685                NaN  155000      155000
# 2     None  179576419   MLA401685                NaN   73600       73600
# 3     None  685332863   MLA401685                NaN  650000      650000
# 4     None  306853491   MLA401685             2017.0  115000      115000
#
#   original_price  ... location.neighborhood.name  location.city.id  \
# ...

# %%
## me lo guardo en Csv y donde lo guarda?!?!??!#jq.  hay q decirle donde en Jupyter notebook

#data.to_csv (r'C:\Users\quintej\Desktop\MCD\Laboratorio de Implementacion 2\DMA_LABO_Austral_2021_rosario-main\Notebooks\dia_5\datos.csv', index = None)

#Para colab
#from google.colab import files
#files.download('datos.csv')

# %%
#Veamos que hay en attributes. Si ponemos type, vamos aver que es un listado de diccionarios
#Vamos a tener que buscar el elemento que tenga m2, area o algo parecido
indices=[]
for i,s in enumerate(final_list[0]['attributes']):
    for j in s:
        if 'AREA' in str(s[j]):
            indices.append([i,s])

# %%
#¿Por que nos salta error?
listado=[]
i=0
for elemento in final_list:
    print(i)
    i+=1
    listado.append(pd.to_numeric(elemento['attributes']['value_name'][0:-2],errors='coerce'))
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-f392778eab72> in <module>
#       5     print(i)
#       6     i+=1
# ----> 7     listado.append(pd.to_numeric(elemento['attributes']['value_name'][0:-2],errors='coerce'))
#
# TypeError: list indices must be integers or slices, not str

# %%
#Definimos una función para traer el elemento que queremos
def traerdato(elemento,rama,subrama,valor='value_name'):
    indices=[]
    for i,s in enumerate(elemento[rama]):
        for j in s:
            if subrama in str(s[j]):
                indices.append([i,s])
    return indices[0][1][valor]

# %%
traerdato(elemento,'attributes','COVERED_AREA','value_name')
# Out:
# '0 m²'

# %%
#probemos de nuevo
listado=[]
for elemento in final_list:
    listado.append(pd.to_numeric(traerdato(elemento,'attributes','COVERED_AREA')[0:-2],errors='coerce'))

# %%
listado
# Out:
# [0,
#  94,
#  0,
#  290,
#  75,
#  98,
#  150,
#  68,
#  85,
#  223,
#  0,
#  120,
#  120,
#  270,
#  250,
#  702,
#  48,
#  90,
#  564,
#  124,
#  69,
#  150,
#  360,
#  284,
#  0,
#  104,
#  550,
#  300,
#  170,
#  173,
#  95,
#  350,
#  180,
#  96,
#  270,
#  200,
#  164,
#  202,
#  175,
#  200,
#  170,
#  107,
#  325,
#  310,
#  105,
#  288,
#  67,
#  255,
#  265,
#  140,
#  68,
#  0,
#  0,
#  80,
#  72,
#  507,
#  150,
#  120,
#  385,
#  110,
#  135,
#  238,
#  187,
#  0,
#  26,
#  318,
#  155,
#  272,
#  131,
#  789,
#  81,
#  176,
#  140,
#  120,
#  150,
#  330,
#  0,
#  120,
#  140,
#  207,
#  550,
#  206,
#  300,
#  150,
#  150,
#  107,
#  290,
#  339,
#  170,
#  140,
#  150,
#  170,
#  279,
#  230,
#  163,
#  575,
#  158,
#  185,
#  100,
#  0,
#  184,
#  212,
#  172,
#  170,
#  200,
#  110,
#  190,
#  0,
#  125,
#  220,
#  100,
#  241,
#  177,
#  168,
#  196,
#  355,
#  247,
#  155,
#  134,
#  170,
#  496,
#  205,
#  457,
#  190,
#  70,
#  99,
#  320,
#  66,
#  215,
# ...

# %%
data['covered_area']=pd.Series(listado)

# %%
#Area total
listado1=[]
for elemento in final_list:
    listado1.append(pd.to_numeric(traerdato(elemento,'attributes','TOTAL_AREA')[0:-2],errors='coerce'))

# %%
data['total_area']=pd.Series(listado1)

# %%
indices=[]
for i,s in enumerate(final_list[0]['attributes']):
    for j in s:
        if 'PROPERTY_AGE' in str(s[j]):
            indices.append([i,s])

# %%
indices
# Out:
# [[33,
#   {'id': 'PROPERTY_AGE',
#    'name': 'Antigüedad',
#    'value_id': None,
#    'value_name': '10 años',
#    'value_struct': {'number': 10, 'unit': 'años'},
#    'values': [{'id': None,
#      'name': '10 años',
#      'struct': {'number': 10, 'unit': 'años'}}],
#    'attribute_group_id': 'FIND',
#    'attribute_group_name': 'Ficha técnica'}]]

# %%
indices=[]
for i,s in enumerate(final_list[0]['attributes']):
    for j in s:
        if 'PROPERTY_AGE' in str(s[j]):
            indices.append([i,s])

# %%
indices
# Out:
# [[33,
#   {'id': 'PROPERTY_AGE',
#    'name': 'Antigüedad',
#    'value_id': None,
#    'value_name': '10 años',
#    'value_struct': {'number': 10, 'unit': 'años'},
#    'values': [{'id': None,
#      'name': '10 años',
#      'struct': {'number': 10, 'unit': 'años'}}],
#    'attribute_group_id': 'FIND',
#    'attribute_group_name': 'Ficha técnica'}]]

# %%
#Definimos una función para traer el elemento que queremos
def traerdato(elemento,rama,subrama,valor='value_name'):
    indices=[]
    for i,s in enumerate(elemento[rama]):
        for j in s:
            if subrama in str(s[j]):
                indices.append([i,s])
    return indices[0][1][valor]

# %%
traerdato(elemento,'attributes','PROPERTY_AGE','value_name')
# Out:
# '12 años'

# %%
#PropAge
listado2=[]
for elemento in final_list:
    listado2.append(pd.to_numeric(traerdato(elemento,'attributes','PROPERTY_AGE')[0:-4],errors='coerce'))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-152-8b95c9f6d46c> in <module>
#       2 listado2=[]
#       3 for elemento in final_list:
# ----> 4     listado2.append(pd.to_numeric(traerdato(elemento,'attributes','PROPERTY_AGE')[0:-4],errors='coerce'))
#
# <ipython-input-144-ea30bfeb6856> in traerdato(elemento, rama, subrama, valor)
#       6             if subrama in str(s[j]):
#       7                 indices.append([i,s])
# ----> 8     return indices[0][1][valor]
#
# IndexError: list index out of range

# %%
final_list[3]
# Out:
# {'id': 'MLA929584796',
#  'site_id': 'MLA',
#  'title': 'Casa - Rosario',
#  'subtitle': None,
#  'seller_id': 685332863,
#  'category_id': 'MLA401685',
#  'official_store_id': None,
#  'price': 650000,
#  'base_price': 650000,
#  'original_price': None,
#  'currency_id': 'USD',
#  'initial_quantity': 1,
#  'available_quantity': 1,
#  'sold_quantity': 0,
#  'sale_terms': [{'id': 'IS_FINANCEABLE',
#    'name': 'Es financiable',
#    'value_id': '242084',
#    'value_name': 'No',
#    'value_struct': None,
#    'values': [{'id': '242084', 'name': 'No', 'struct': None}]}],
#  'buying_mode': 'classified',
#  'listing_type_id': 'gold_premium',
#  'start_time': '2021-07-15T15:06:23.000Z',
#  'stop_time': '2021-09-13T04:00:00.000Z',
#  'condition': 'used',
#  'permalink': 'https://casa.mercadolibre.com.ar/MLA-929584796-casa-rosario-_JM',
#  'thumbnail_id': '954343-MLA46752983128_072021',
#  'thumbnail': 'http://http2.mlstatic.com/D_954343-MLA46752983128_072021-I.jpg',
# ...
